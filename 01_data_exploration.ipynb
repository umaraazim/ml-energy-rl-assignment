# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_excel('ENB2012_data.xlsx')
df.columns = ['Compactness','SurfaceArea','WallArea','RoofArea',
'Height','Orientation','GlazingArea','GlazingDist',
'HeatingLoad','CoolingLoad']

# %%
print(df.shape)
# Out:
# (768, 10)

# %%
df.head()
# Out:
#    Compactness  SurfaceArea  WallArea  RoofArea  Height  Orientation  \
# 0         0.98        514.5     294.0    110.25     7.0            2
# 1         0.98        514.5     294.0    110.25     7.0            3
# 2         0.98        514.5     294.0    110.25     7.0            4
# 3         0.98        514.5     294.0    110.25     7.0            5
# 4         0.90        563.5     318.5    122.50     7.0            2
#
#    GlazingArea  GlazingDist  HeatingLoad  CoolingLoad
# 0          0.0            0        15.55        21.33
# 1          0.0            0        15.55        21.33
# 2          0.0            0        15.55        21.33
# 3          0.0            0        15.55        21.33
# 4          0.0            0        20.84        28.28
